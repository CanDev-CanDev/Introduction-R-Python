# %% [markdown]
# # Welcome to the Course
#
# This is the repository for the course: **Python Data Science and Machine Learning Bootcamp**
# https://www.udemy.com/python-for-data-science-and-machine-learning-bootcamp/learn/v4/t/lecture/5733180?start=375
#
#
# Thank you so much for enrolling in the course!
#
# ## Overview of this Repository
#
# This repository contains everything you need for the course, it has all the notebooks, links on this repository https://github.com/CanDev-CanDev/Introduction-R-Python

# %% [markdown]
# ### We want to use requests python package and BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
## Look at robots and terms of service

# %%
robots = "https://www.statcan.gc.ca/robots.txt"
rrobots = requests.get(robots)
print(rrobots.text)
# Out:
# # robots.txt for http://www.statcan.gc.ca/
# # Syntax checker http://tool.motoricerca.info/robots-checker.phtml
#
# User-agent: gsa-crawler
# Disallow: /
#
# User-agent: HTTrack
# Disallow: /
#
# User-agent: AhrefsBot
# Disallow: /
#
# User-agent: SiteSucker
# User-agent: SiteSucker/2.3.3
# Disallow: /
#
# User-agent: integrity
# User-agent: integrity/4
# Disallow: /
#
# User-agent: Microsoft URL Control
# Disallow: /
#
# User-agent: Ultraseek
# Disallow:
#
# User-agent: LucidWorks
# Disallow:
#
# User-agent: *
# Crawl-delay: 2
# #
# Disallow: /error-erreur/
# #
# Disallow: /beta/
# #
# Disallow: /pub/12-591-x/2006001/
# Disallow: /pub/12-591-x/12-591-x2006001-eng.htm
# Disallow: /pub/12-591-x/12-591-x2006001-fra.htm
# #
# Disallow: /daily-quotidien/080306/be080306a-eng.htm
# Disallow: /daily-quotidien/080306/be080306a-fra.htm
# #
# Disallow: /daily-quotidien/09
# Disallow: /daily-quotidien/10
# Disallow: /daily-quotidien/11
# Disallow: /daily-quotidien/12
# ...

# %%
# Create a url

# %%
url = "https://catalogue.uottawa.ca/en/graduate/master-arts-economics/"

# %%
# Create a requests to server
# Some side notes are robots.txt and

# %%
create_connection = requests.get(url)

# %%
# Create a soup object

# %%
soup = BeautifulSoup(create_connection.content,'html.parser')

# %%
# Read terms of services and robots.txt

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html dir="ltr" lang="en" xml:lang="en">
# <head>
# <title>Master of Arts Economics &lt; uOttawa</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/search/opensearch.xml" rel="search" title="Catalog" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/fonts/font-awesome/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400italic,600italic,700italic,400,600,700" rel="stylesheet" type="text/css"/>
# <link href="/css/screen.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css/handheld.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# Alright so now we have soup object let's view the html code

# %%
for item in soup.findAll("p"):
    print(item.text)
# Out:
# To change text size, use the browser commands.
# In the toolbar, select View > Zoom > Zoom In, Reset or Zoom Out. On the keyboard, press COMMAND + to zoom in, COMMAND - to zoom out or COMMAND 0 to reset.
# In the toolbar, select View > Zoom In,  Actual Size or Zoom Out. On the keyboard, press COMMAND + (Mac) or CTRL + (Windows) to zoom in, COMMAND - (Mac) or CTRL - (Windows) to zoom out or COMMAND 0 (Mac) or CTRL 0 (Windows) to view actual size
# In the toolbar, select View > Zoom > Zoom In, Reset or Zoom Out. On the keyboard, press COMMAND + (Mac) or CTRL + (Windows) to zoom in, COMMAND - (Mac) or CTRL - (Windows) to zoom out or COMMAND 0 (Mac) or CTRL 0 (Windows) to view actual size
# In the toolbar, select Options > Zoom > Zoom In, Custom or Zoom Out. On the keyboard, press CTRL + to zoom in, CTRL - to zoom out or CTRL 0 to reset.
# ...

# %%
soup.findAll("p")
# Out:
# [<p>To change text size, use the browser commands.</p>,
#  <p>In the toolbar, select View &gt; Zoom &gt; Zoom In, Reset or Zoom Out. On the keyboard, press COMMAND + to zoom in, COMMAND - to zoom out or COMMAND 0 to reset.</p>,
#  <p>In the toolbar, select View &gt; Zoom In,  Actual Size or Zoom Out. On the keyboard, press COMMAND + (Mac) or CTRL + (Windows) to zoom in, COMMAND - (Mac) or CTRL - (Windows) to zoom out or COMMAND 0 (Mac) or CTRL 0 (Windows) to view actual size</p>,
#  <p>In the toolbar, select View &gt; Zoom &gt; Zoom In, Reset or Zoom Out. On the keyboard, press COMMAND + (Mac) or CTRL + (Windows) to zoom in, COMMAND - (Mac) or CTRL - (Windows) to zoom out or COMMAND 0 (Mac) or CTRL 0 (Windows) to view actual size</p>,
#  <p>In the toolbar, select Options &gt; Zoom &gt; Zoom In, Custom or Zoom Out. On the keyboard, press CTRL + to zoom in, CTRL - to zoom out or CTRL 0 to reset.</p>,
# ...
